# %%
# %reload_ext soup
# Out:
# Monkey patch BeautifulSoup with custom rendering
# Push 'BeautifulSoup' of 'bs4' into current context
# Push 'urlopen' of 'urllib2' into current context
# Push 'p' shortcut into current context
# Push 'request' into current context

# %%
# !pip install beautifulsoup4
# Out:
# Downloading/unpacking beautifulsoup4
# ...
#   Storing download in cache at /tmp/.pip-download-cache/https%3A%2F%2Fpypi.python.org%2Fpackages%2Fsource%2Fb%2Fbeautifulsoup4%2Fbeautifulsoup4-4.3.2.tar.gz
#   Running setup.py egg_info for package beautifulsoup4
#
# ...
#   Running setup.py install for beautifulsoup4
# ...
# Cleaning up...

# %%
from urllib2 import urlopen

soup = p("http://cerkinfo.be")

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="fr">
# <head>
# <meta charset="utf-8"/>
# <title>ULB:Cerkinfo: News </title>
# <link href="http://fonts.googleapis.com/css?family=Ubuntu" rel="stylesheet" type="text/css">
# <meta content="CI, Cerkinfo, ULB, Cercle Informatique" name="Keywords"/>
# <link href="/site_media/favicon.png" media="all" rel="shortcut icon" type="image/png"/>
# <!-- The Game -->
# <link href="/site_media/css/style.css" media="screen" rel="stylesheet" title="Design" type="text/css"/>
# <!--[if IE]>
# 	   <link rel="stylesheet" media="screen" type="text/css" title="DesignIE" href="css/style_ie.css" />
# 	<![endif]-->
# <link href="/rss" rel="alternate" title="RSS - Cercle Informatique" type="application/rss+xml"/>
# <link href="/pv/rss" rel="alternate" title="RSS - PV's du Cercle Informatique" type="application/rss+xml"/>
# <script src="/site_media/ckeditor/ckeditor/ckeditor.js" type="text/javascript"></script>
# ...

# %%
soup.find('div', id='content')('div')[3:4]
# Out:
# [<div class="news">
# <h2>AG de mi-mandat le 29 novembre</h2>
# <p class="newsheader">par PullAndBiere le 25 novembre 2013 22:42:53</p>
# <p class="newstext">Bonjour, le cercle informatique organise une AG de mi-mandat le vendredi 29 novembre au Forum E.<br>
# <br>
# Au programme :<br>
# 15h : Présentation des plans (ce que le délégué prévoit de faire durant son mandat) et petit BM de chaque postes<br>
# 17h : Nouvelles élections pour certains postes (voir plus bas)<br>
# 18h : Point trésorerie<br>
# <br>
# Plus d'informations sur les postes sont disponibles sur <!-- m --><a class="postlink" href="http://wiki.cerkinfo.be/2007:vade_mecum_du_comite">http://wiki.cerkinfo.be/2007:vade_mecum_du_comite</a><!-- m --> <br>
# <br>
# Les postes à pourvoir sont :<br>
# Forum de l'emploi :<br>
# -<br>
# <br>
# Bar (2 places) :<br>
# -<br>
# -<br>
# <br>
# Culture/Sport/Social/Librex :<br>
# - Loïs Postula﻿<br>
# <br>
# Webmaster :<br>
# - Romain Fontaine<br>
# <br>
# Photos :<br>
# ...
