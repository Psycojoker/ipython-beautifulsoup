# %%
# %reload_ext soup
# Out:
# Monkey patch BeautifulSoup with custom rendering
# Push 'BeautifulSoup' of 'BeautifulSoup' into current context
# Push 'urlopen' of 'urllib2' into current context
# Push 'p' shortcut into current context

# %%
from urllib2 import urlopen

soup = p("http://cerkinfo.be")

# %%
soup
# Out:
# <!DOCTYPE HTML>
# <html lang="fr">
# <head>
# <meta charset="utf-8" />
# <title>ULB:Cerkinfo: News </title>
# <link href="http://fonts.googleapis.com/css?family=Ubuntu" rel="stylesheet" type="text/css" />
# <meta name="Keywords" content="CI, Cerkinfo, ULB, Cercle Informatique" />
# <link rel="shortcut icon" type="image/png" media="all" href="/site_media/favicon.png" />
# <!-- The Game -->
# <link rel="stylesheet" media="screen" type="text/css" title="Design" href="/site_media/css/style.css" />
# <!--[if IE]&gt;
# 	   &lt;link rel="stylesheet" media="screen" type="text/css" title="DesignIE" href="css/style_ie.css"  /&gt;
# 	&lt;![endif]-->
# <link rel="alternate" type="application/rss+xml" title="RSS - Cercle Informatique" href="/rss" />
# <link rel="alternate" type="application/rss+xml" title="RSS - PV's du Cercle Informatique" href="/pv/rss" />
# <script type="text/javascript" src="/site_media/ckeditor/ckeditor/ckeditor.js"></script>
# ...

# %%
soup.find('div', id='content')('div', 'news')
# Out:
# [<div class="news">
# <h2>Pré-TD raclette 2013</h2>
# <p class="newsheader">par Fumier le 12 décembre 2013 10:42:07</p>
# <p class="newstext">Une fois n'est pas coutume : à l'approche des fêtes de fin d'année et de ses divers plaisirs, le Cercle Informatique vous convie à son 36ème souper raclette du pré-td Noel.<br />
# <br />
# <b>!!! ATTENTION !!! </b><br />
# Places limitées à 25 personnes.<br />
# <br />
# <b>Quand ?</b> Le jeudi 19 décembre, à 19h30.<br />
# <b>Où ?</b> Au CI.<br />
# <b>Nombre de places ?</b> 25 places<br />
# <b>Prix ?</b> Reste encore à déterminer selon le fournisseur du vin et de victuailles (probablement 9e sans vin et 16e avec).<br />
# <b>Réduction ?</b> Moins 3 euros si tu rapportes ton appareil !<br />
# <b>Pourquoi ?</b> Pour vous délecter d'une onctueuse raclette avant une soirée qui s'annonce alcoolisée<br />
# <br />
# ...
